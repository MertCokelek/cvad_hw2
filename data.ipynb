# %%
import pickle, zlib, os

# %%
ex_list = pickle.load(open("/home/mcokelek21/argo/ex_list", "rb"))

# %%
instance = pickle.loads(zlib.decompress(ex_list[0]))
instance['file_name'] = instance['file_name'].replace('/datasets/', '/home/mcokelek21/Cluster/datasets/')

# %%
instance
# Out:
# {'file_name': '/home/mcokelek21/Cluster/datasets/argoverse/forecasting/train/100000.csv',
#  'start_time': 315967953.24975896,
#  'city_name': 'PIT',
#  'cent_x': 2409.534858387793,
#  'cent_y': 913.8636668930446,
#  'agent_pred_index': 20,
#  'two_seconds': 1.8995460867881775,
#  'angle': 0.8508501407635968,
#  'trajs': [],
#  'agents': [array([[-2.56633953e-01, -3.73160378e+01,  0.00000000e+00],
#          [-2.44739444e-01, -3.55021952e+01,  9.75989103e-02],
#          [-2.26554822e-01, -3.36589975e+01,  1.99477911e-01],
#          [-1.77605363e-01, -3.17933040e+01,  3.03513169e-01],
#          [-1.56038202e-01, -2.99259557e+01,  3.97103071e-01],
#          [-1.06160117e-01, -2.79935476e+01,  5.00079393e-01],
#          [-7.91791215e-02, -2.61001975e+01,  6.00292385e-01],
#          [-9.88486282e-02, -2.41550925e+01,  7.00370669e-01],
#          [-5.88378666e-02, -2.22378155e+01,  7.98432231e-01],
#          [-7.32012272e-02, -2.03841786e+01,  9.00504231e-01],
# ...

# %%
os.path.isfile(instance['file_name'])
# Out:
# True
